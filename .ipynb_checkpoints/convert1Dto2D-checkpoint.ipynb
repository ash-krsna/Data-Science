# %%
import numpy as np

x = [10,20,30,40,50,60,70,80,90,15,25,35,55,65,75,85]
print("Val of x = {} and type = {}".format(x,type(x)))
a = np.array(x)
print("-"*50)
print("Content of ndarray = {} Type = {}".format(a,type(a)))
print("Dimension of a =",a.ndim)
print("D type of a",a.dtype)
print("Size of a =",a.size)
print("Shape of a=",a.shape)
print("-"*50)
#convert 1D data in to 2-D in the form of 4 rows x 4 Columns
a.shape = (4,4)
print("Content of ndarray = {} Type = {}".format(a,type(a)))
print("Dimension of a =",a.ndim)
print("D type of a",a.dtype)
print("Size of a =",a.size)
print("Shape of a=",a.shape)
print("-"*50)
#
# Out:
# Val of x = [10, 20, 30, 40, 50, 60, 70, 80, 90, 15, 25, 35, 55, 65, 75, 85] and type = <class 'list'>
# --------------------------------------------------
# Content of ndarray = [10 20 30 40 50 60 70 80 90 15 25 35 55 65 75 85] Type = <class 'numpy.ndarray'>
# Dimension of a = 1
# D type of a int64
# Size of a = 16
# Shape of a= (16,)
# --------------------------------------------------
# Content of ndarray = [[10 20 30 40]
#  [50 60 70 80]
#  [90 15 25 35]
#  [55 65 75 85]] Type = <class 'numpy.ndarray'>
# Dimension of a = 2
# D type of a int64
# Size of a = 16
# Shape of a= (4, 4)
# --------------------------------------------------
