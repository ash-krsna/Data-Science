# %%
x = 10
print("val of x = {} and type = {}".format(x,type(x)))
a = np.array(x)
print('-'*50)
print("Content of ndarray = {} Type = {}".format(a,type(a)))

# %%
import numpy as np

# %%
x = 10
print("val of x = {} and type = {}".format(x,type(x)))
a = np.array(x)
print('-'*50)
print("Content of ndarray = {} Type = {}".format(a,type(a)))
