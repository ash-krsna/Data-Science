# %%
import numpy as np
x = [10,20,30,40,50,60]
print("Val of x = {} and type = {}".format(x,type(x)))
a = np.array(x)
print("-"*50)
print("Content of ndarray = {} type = {}".format(a,type(a)))
print("Dimension of a =",a.ndim)
print("D type of a =",a.dtype)
print("Size of a =",a.size)
print("Shape of a =",a.shape)
# Out:
# Val of x = [10, 20, 30, 40, 50, 60] and type = <class 'list'>
# --------------------------------------------------
# Content of ndarray = [10 20 30 40 50 60] type = <class 'numpy.ndarray'>
# Dimension of a = 1
# D type of a = int64
# Size of a = 6
# Shape of a = (6,)
